# %% [markdown]
# # EDA : Sales data

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load the data

# %%
# Load the Excel file
file_path = "supermarkt_sales.xlsx"
df = pd.read_excel(file_path, skiprows=3)

# %%
# Display the first few rows of the data
df.head()
# Out:
#    Unnamed: 0   Invoice ID Branch       City Customer_type  Gender
# 0         NaN  750-67-8428      A     Yangon        Member  Female  \
# 1         NaN  226-31-3081      C  Naypyitaw        Normal  Female
# 2         NaN  631-41-3108      A     Yangon        Normal    Male
# 3         NaN  123-19-1176      A     Yangon        Member    Male
# 4         NaN  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05  \
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income
# ...

# %%
# Drop the first column
df = df.drop(df.columns[0], axis=1)

# %%
# Display the first few rows of the data
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender
# 0  750-67-8428      A     Yangon        Member  Female  \
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date
# 0       Health and beauty       74.69         7  26.1415  548.9715 2021-01-05  \
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2021-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2021-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2021-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2021-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415  \
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ## 3. Clean the data

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer_type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# Quick data overview
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total
# count  1000.000000  1000.000000  1000.000000  1000.000000  \
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage
# count                        1000  1000.00000              1000.000000  \
# mean   2021-02-14 00:05:45.600000   307.58738                 4.761905
# min           2021-01-01 00:00:00    10.17000                 4.761905
# 25%           2021-01-24 00:00:00   118.49750                 4.761905
# 50%           2021-02-13 00:00:00   241.76000                 4.761905
# ...

# %%
df['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Customer_type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %% [markdown]
# ## 4. Basic Summary Statistics

# %%
print(df[['Unit price', 'Quantity', 'Total', 'gross income', 'Rating']].describe())
# Out:
#         Unit price     Quantity        Total  gross income      Rating
# count  1000.000000  1000.000000  1000.000000   1000.000000  1000.00000
# mean     55.672130     5.510000   322.966749     15.379369     6.97270
# std      26.494628     2.923431   245.885335     11.708825     1.71858
# min      10.080000     1.000000    10.678500      0.508500     4.00000
# 25%      32.875000     3.000000   124.422375      5.924875     5.50000
# 50%      55.230000     5.000000   253.848000     12.088000     7.00000
# 75%      77.935000     8.000000   471.350250     22.445250     8.50000
# max      99.960000    10.000000  1042.650000     49.650000    10.00000

# %% [markdown]
# ## 5. Gender Distribution: Analyze the distribution of sales based on gender

# %%
# Plotting


sns.countplot(x='Gender', data=df)
plt.show()

# %% [markdown]
# ## 6. Sales per City or Branch: To see the sales across different cities or branches

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Customer_type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
city_sales = df.groupby('City')['Total'].sum()
print(city_sales)

# Plot sales by city
city_sales.plot(kind='bar', title='Total Sales by City')
plt.show()
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Total, dtype: float64

# %% [markdown]
# ## 7. Sales by Product Line: Understand which product lines generate the most revenue

# %%
product_sales = df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
print(product_sales)

# Plotting sales by product line
sns.barplot(x=product_sales.index, y=product_sales.values)
plt.xticks(rotation=45)
plt.title('Sales by Product Line')
plt.show()
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %% [markdown]
# ## 8. Customer Type and Payment Method: You can analyze which customer type uses which payment method

# %%
customer_payment = pd.crosstab(df['Customer_type'], df['Payment'])
print(customer_payment)

customer_payment.plot(kind='bar', stacked=True)
plt.title('Customer Type vs Payment Method')
plt.show()
# Out:
# Payment        Cash  Credit card  Ewallet
# Customer_type
# Member          168          172      161
# Normal          176          139      184

# %% [markdown]
# ## 9. Sales Over Time: If you want to analyze sales trends over time

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Group by Date
daily_sales = df.groupby('Date')['Total'].sum()
daily_sales.plot(kind='line', title='Sales Over Time')
plt.show()

# %% [markdown]
# ## 10. Correlation Analysis

# %%
correlation = df[['Unit price', 'Quantity', 'Total', 'gross income', 'Rating']].corr()
print(correlation)

# Plot heatmap of the correlation matrix
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
#               Unit price  Quantity     Total  gross income    Rating
# Unit price      1.000000  0.010778  0.633962      0.633962 -0.008778
# Quantity        0.010778  1.000000  0.705510      0.705510 -0.015815
# Total           0.633962  0.705510  1.000000      1.000000 -0.036442
# gross income    0.633962  0.705510  1.000000      1.000000 -0.036442
# Rating         -0.008778 -0.015815 -0.036442     -0.036442  1.000000

# %% [markdown]
# ## 11.  Customer Segmentation

# %%
def categorize_customer(total):
    if total < 200:
        return 'Low Spender'
    elif 200 <= total < 500:
        return 'Medium Spender'
    else:
        return 'High Spender'

df['Customer Category'] = df['Total'].apply(categorize_customer)

# Plot the customer segments
sns.countplot(x='Customer Category', data=df)
plt.title('Customer Segments by Spending')
plt.show()

# %% [markdown]
# ## 12. Time Series Analysis

# %%
# Plot sales by time of day
time_sales = df.groupby('Time')['Total'].sum()
time_sales.plot(kind='line', title='Sales by Hour of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ## 13. Gross Income Analysis

# %%
branch_income = df.groupby('Branch')['gross income'].sum()
print(branch_income)

# Plot income by branch
branch_income.plot(kind='bar', title='Gross Income by Branch')
plt.ylabel('Gross Income')
plt.show()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# ## 14. Rating Distribution

# %%
sns.histplot(df['Rating'], kde=True)
plt.title('Distribution of Customer Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# Rating based on Product Line
sns.boxplot(x='Product line', y='Rating', data=df)
plt.xticks(rotation=45)
plt.title('Customer Ratings by Product Line')
plt.show()

# %% [markdown]
# ## 15. Sales by Payment Method

# %%
payment_sales = df.groupby('Payment')['Total'].sum()
payment_sales.plot(kind='bar', title='Sales by Payment Method', color='skyblue')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ## 16. Revenue Prediction (Machine Learning)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Convert categorical columns into dummy/one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Branch', 'City', 'Customer_type', 'Gender', 'Product line', 'Payment'], drop_first=True)

X = df_encoded[['Quantity', 'Unit price', 'gross income']]  # You can add more relevant features
y = df_encoded['Total']

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Check the model's performance
print('Model R-squared:', model.score(X_test, y_test))
# Out:
# Model R-squared: 1.0

# %% [markdown]
# ## 17.  Actual vs. Predicted Values
#
# This plot helps us to see how well the model is predicting the Total sales.

# %%
# Predict on test data
y_pred = model.predict(X_test)

# Plot Actual vs Predicted
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Total Sales')
plt.ylabel('Predicted Total Sales')
plt.title('Actual vs Predicted Sales')
plt.show()

# %% [markdown]
# ## 18. Residual Plot
#
# The residual plot helps us assess if our model's errors (residuals) are normally distributed and if there are patterns in prediction errors.

# %%
# Calculate residuals
residuals = y_test - y_pred

# Plot residuals
plt.scatter(y_pred, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Total Sales')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# ## 19. Distribution of Residuals (Histogram):
# Check if the residuals are normally distributed, which is a good assumption for linear regression.

# %%
# Plot histogram of residuals
sns.histplot(residuals, kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.show()

# %% [markdown]
# ## 20.  R-squared Score Visualization:
# While this is a single value, we can visualize it along with other performance metrics for better context.

# %%
from sklearn.metrics import r2_score, mean_squared_error

r_squared = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# Bar plot for R-squared and MSE
metrics = {'R-squared': r_squared, 'MSE': mse}
plt.bar(metrics.keys(), metrics.values(), color=['blue', 'green'])
plt.title('Model Performance Metrics')
plt.show()

# %% [markdown]
# ## 21. Learning Curve:
# A learning curve helps to evaluate whether the model is underfitting or overfitting by plotting the training and validation scores as the number of training samples increases. The learning curve can be used to determine the optimal number of training samples for the model.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=5, scoring='r2', n_jobs=-1)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training Score')
plt.plot(train_sizes, test_scores_mean, label='Cross-Validation Score')
plt.xlabel('Training Size')
plt.ylabel('R-squared Score')
plt.title('Learning Curve')
plt.legend()
plt.show()
